# %%
# %pip install --upgrade pip
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('data/bank_transactions_data_2.csv',
                 sep=',',
                 header=0,
                 index_col=0,
                 skiprows=0,
                 encoding='utf-8',
                 na_values=['NA','?'],
                 parse_dates=['TransactionDate'],
                 skip_blank_lines=True,
                 low_memory=False)
df.head(n=15)
# Out:
#               AccountID  TransactionAmount     TransactionDate  \
# TransactionID
# TX000001        AC00128              14.09 2023-04-11 16:29:14
# TX000002        AC00455             376.24 2023-06-27 16:44:19
# TX000003        AC00019             126.29 2023-07-10 18:16:08
# TX000004        AC00070             184.50 2023-05-05 16:32:11
# TX000005        AC00411              13.45 2023-10-16 17:51:24
# TX000006        AC00393              92.15 2023-04-03 17:15:01
# TX000007        AC00199               7.08 2023-02-15 16:36:48
# TX000008        AC00069             171.42 2023-05-08 17:47:59
# TX000009        AC00135             106.23 2023-03-21 16:59:46
# TX000010        AC00385             815.96 2023-03-31 16:06:57
# TX000011        AC00150              17.78 2023-03-14 16:46:10
# TX000012        AC00459             190.02 2023-02-06 17:30:00
# TX000013        AC00392             494.52 2023-06-07 17:21:28
# TX000014        AC00264             781.76 2023-11-20 16:39:15
# ...

# %%
df.describe()
# Out:
#        TransactionAmount  CustomerAge  TransactionDuration  LoginAttempts  \
# count        2512.000000  2512.000000          2512.000000    2512.000000
# mean          297.593778    44.673965           119.643312       1.124602
# std           291.946243    17.792198            69.963757       0.602662
# min             0.260000    18.000000            10.000000       1.000000
# 25%            81.885000    27.000000            63.000000       1.000000
# 50%           211.140000    45.000000           112.500000       1.000000
# 75%           414.527500    59.000000           161.000000       1.000000
# max          1919.110000    80.000000           300.000000       5.000000
#
#        AccountBalance
# count     2512.000000
# mean      5114.302966
# std       3900.942499
# min        101.250000
# 25%       1504.370000
# 50%       4735.510000
# 75%       7678.820000
# max      14977.990000

# %%
df.tail(n=10)
# Out:
#               AccountID  TransactionAmount     TransactionDate  \
# TransactionID
# TX002503        AC00069             603.54 2023-04-21 16:22:38
# TX002504        AC00427             270.25 2023-11-06 16:56:41
# TX002505        AC00047             123.38 2024-01-01 17:21:56
# TX002506        AC00377             577.12 2023-01-27 17:38:07
# TX002507        AC00258              92.24 2023-04-13 17:45:33
# TX002508        AC00297             856.21 2023-04-26 17:09:36
# TX002509        AC00322             251.54 2023-03-22 17:36:48
# TX002510        AC00095              28.63 2023-08-21 17:08:50
# TX002511        AC00118             185.97 2023-02-24 16:24:46
# TX002512        AC00009             243.08 2023-02-14 16:21:23
#
#               TransactionType          Location DeviceID      IP Address  \
# TransactionID
# TX002503                Debit       Albuquerque  D000321  112.86.148.212
# TX002504                Debit            Tucson  D000224  147.114.91.132
# ...

# %%
df.isnull().sum() #to check null values
# Out:
# TransactionID              0
# AccountID                  0
# TransactionAmount          0
# TransactionDate            0
# TransactionType            0
# Location                   0
# DeviceID                   0
# IP Address                 0
# MerchantID                 0
# Channel                    0
# CustomerAge                0
# CustomerOccupation         0
# TransactionDuration        0
# LoginAttempts              0
# AccountBalance             0
# PreviousTransactionDate    0
# dtype: int64

# %%
df.shape # Not a function
# Out:
# (2512, 15)

# %%
df.dtypes
# Out:
# AccountID                          object
# TransactionAmount                 float64
# TransactionDate            datetime64[ns]
# TransactionType                    object
# Location                           object
# DeviceID                           object
# IP Address                         object
# MerchantID                         object
# Channel                            object
# CustomerAge                         int64
# CustomerOccupation                 object
# TransactionDuration                 int64
# LoginAttempts                       int64
# AccountBalance                    float64
# PreviousTransactionDate            object
# dtype: object

# %%
df['TransactionType']=df['TransactionType'].astype(dtype='string')
df.dtypes
# Out:
# AccountID                          object
# TransactionAmount                 float64
# TransactionDate            datetime64[ns]
# TransactionType            string[python]
# Location                           object
# DeviceID                           object
# IP Address                         object
# MerchantID                         object
# Channel                            object
# CustomerAge                         int64
# CustomerOccupation                 object
# TransactionDuration                 int64
# LoginAttempts                       int64
# AccountBalance                    float64
# PreviousTransactionDate            object
# dtype: object

# %%
df['TransactionType'].value_counts()
# Out:
# TransactionType
# Debit     1944
# Credit     568
# Name: count, dtype: int64

# %%
df = pd.read_csv('data/bank_transactions_data_2.csv')
df.shape
# Out:
# (2513, 16)

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (2512, 16)

# %%
df.columns
# Out:
# Index(['TransactionID', 'AccountID', 'TransactionAmount', 'TransactionDate',
#        'TransactionType', 'Location', 'DeviceID', 'IP Address', 'MerchantID',
#        'Channel', 'CustomerAge', 'CustomerOccupation', 'TransactionDuration',
#        'LoginAttempts', 'AccountBalance', 'PreviousTransactionDate'],
#       dtype='object')

# %%
df.drop(['DeviceID'],axis=1,inplace=True)
df.columns
# Out:
# Index(['TransactionID', 'AccountID', 'TransactionAmount', 'TransactionDate',
#        'TransactionType', 'Location', 'IP Address', 'MerchantID', 'Channel',
#        'CustomerAge', 'CustomerOccupation', 'TransactionDuration',
#        'LoginAttempts', 'AccountBalance', 'PreviousTransactionDate'],
#       dtype='object')

# %%
df.sort_values(by=['AccountID','TransactionID','TransactionDate'],ascending=True,inplace=True)

# %%
df.head()
# Out:
#      TransactionID AccountID  TransactionAmount      TransactionDate  \
# 1313      TX001313   AC00001              47.79  2023-09-15 17:00:20
# 2017      TX002017   AC00001             212.97  2023-11-14 16:56:34
# 21        TX000021   AC00002              59.32  2023-02-28 16:36:58
# 62        TX000062   AC00002             263.99  2023-05-16 16:07:30
# 1029      TX001029   AC00002             516.47  2023-12-21 17:00:50
#
#      TransactionType     Location      IP Address MerchantID Channel  \
# 1313           Debit       Denver     59.12.96.11       M034  Branch
# 2017           Debit      Atlanta   45.241.13.208       M003  Online
# 21             Debit  Los Angeles   116.44.12.250       M040  Branch
# 62             Debit       Dallas    7.146.35.122       M087  Branch
# 1029          Credit    Charlotte  59.132.247.252       M026     ATM
#
#       CustomerAge CustomerOccupation  TransactionDuration  LoginAttempts  \
# ...

# %% [markdown]
# 1. read_csv()
# 2. head()
# 3. describe()
# 4. tail()
# 5. isnull().sum() - find missing value
# 6. astype()
# 7. value_counts()
# 8. drop_duplicates()
# 9. drop()
# 10. sort_values()
